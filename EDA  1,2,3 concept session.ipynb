# %% [markdown]
# # level 0 Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv("DS1_C5_S1_BankChurn_Data_Concept.csv")
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
#check if the data is consistent or not

# %%
df.head()  #first 5 rows
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
df.tail( )   #last 5 rows
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %%
df.shape
# Out:
# (10127, 19)

# %%
df.columns       #give all the columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Trans_Amt', 'Total_Trans_Ct',
#        'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10034 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             9995 non-null   object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                     0
# Attrition_Flag                0
# Customer_Age                  0
# Gender                       93
# Dependent_count               0
# Education_Level               0
# Marital_Status                0
# Income_Category               0
# Card_Category               132
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                 60
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Avg_Utilization_Ratio         0
# dtype: int64

# %% [markdown]
# # level 1 analysis
# - explore each column
# - slit data into two parts
# - categorial and numerical

# %%
#cannot do analysis on clientnum

# %%
#separating out the categorical and continuous variables

def seperate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:
        if df[column].nunique() < 100:
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous

categorical, continuous = seperate_data_types(df)

#Tabulate is a package used to print the list, dict or any data sets in a proper format; in a table format

from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical, "Continuous":continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  ---------------------
# Attrition_Flag            CLIENTNUM
# Gender                    Customer_Age
# Dependent_count           Credit_Limit
# Education_Level           Total_Revolving_Bal
# Marital_Status            Avg_Open_To_Buy
# Income_Category           Total_Trans_Amt
# Card_Category             Total_Trans_Ct
# Months_on_book            Avg_Utilization_Ratio
# Total_Relationship_Count
# Months_Inactive_12_mon
# Contacts_Count_12_mon

# %%
df["Attrition_Flag"].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df["Attrition_Flag"].nunique()
# Out:
# 2

# %%
df["CLIENTNUM"].unique()
# Out:
# array([768805383, 818770008, 713982108, ..., 716506083, 717406983,
#        714337233], dtype=int64)

# %%
df["CLIENTNUM"].nunique()
# Out:
# 10127

# %%
def info_cat(col):           #categorical 
    print(col)
    print("Unique values:", df[col].unique())
    print("Mode(most repeated values):", df[col].mode()[0])
    print("Missing values:",df[col].isnull().sum())

# %%
info_cat("Attrition_Flag")
# Out:
# Attrition_Flag
# Unique values: ['Existing Customer' 'Attrited Customer']
# Mode(most repeated values): Existing Customer
# Missing values: 0

# %%
def info_num(col):                    #numerical
    print(col)
    print("Mean:",df[col].mean())
    print("Median:",df[col].median())
    print("Mode", df[col].mode()[0])
    print("Standard deviation:",df[col].std())
    print("Minimum value:",df[col].min())
    print("Maximum value:",df[col].max())
    print("Missing value:",df[col].isnull().sum())

# %%
info_num("Credit_Limit")
# Out:
# Credit_Limit
# Mean: 8703.180550312904
# Median: 4557.0
# Mode 34516.0
# Standard deviation: 9190.058901949453
# Minimum value: 1438.3
# Maximum value: 34664.0
# Missing value: 60

# %% [markdown]
# # Attrition_Flag analysis

# %%
info_cat("Attrition_Flag")
# Out:
# Attrition_Flag
# Unique values: ['Existing Customer' 'Attrited Customer']
# Mode(most repeated values): Existing Customer
# Missing values: 0

# %%
dist= df["Attrition_Flag"].value_counts()
dist
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt            
import seaborn as sns
dist= df['Attrition_Flag'].value_counts()

fig, ax=plt.subplots(1,2, figsize= (15,6))       #1,2 is for 1 row and 2 columns  #(15,6) is for the length and width of the graph

ax[0].set_title("count of Attrition_Flag")           #title
labels= list(dist. index)                             #labels

sns.countplot(x= df ['Attrition_Flag'], ax= ax[0])      #this is from seaborn library
plt.pie(dist, labels= labels, autopct="%0.2f%%")       #this is from plt

plt.show()

# %%
def cat_chart(col):
    dist= df[col].value_counts()
    fig, ax=plt.subplots(1,2, figsize= (15,6))       #1,2 is for 1 row and 2 columns  #(15,6) is for the length and width of the graph
    ax[0].set_title("count of"+str(col))           #title
    labels= list(dist. index)                             #labels

    sns.countplot(x= df[col], ax= ax[0])      #this is from seaborn library
    plt.pie(dist, labels= labels, autopct="%0.2f%%")       #this is from plt

    plt.show()

# %%
cat_chart("Attrition_Flag")

# %% [markdown]
# # gender analysis

# %%
info_cat("Gender")
# Out:
# Gender
# Unique values: ['M' 'F' nan]
# Mode(most repeated values): F
# Missing values: 93

# %%
df["Gender"].fillna(df["Gender"].mode()[0], inplace = True)

# %%
df["Gender"].fillna("F", inplace = True)

# %%
info_cat("Gender")
# Out:
# Gender
# Unique values: ['M' 'F']
# Mode(most repeated values): F
# Missing values: 0

# %%
cat_chart("Gender")

# %% [markdown]
# # Dependent_count analysis

# %%
cat_chart("Dependent_count")

# %% [markdown]
# # Education_Level analysis

# %%
cat_chart("Education_Level")

# %%
#interpretation 

#There are 31 percent people are graduated and 20 percent are in High School

# %% [markdown]
# # Marital_Status analysis

# %%
cat_chart("Marital_Status")

# %% [markdown]
# # Income_Category analysis

# %%
cat_chart("Income_Category")

# %% [markdown]
# # Card_Category

# %%
cat_chart("Card_Category")

# %% [markdown]
# # Months_on_book

# %%
cat_chart("Months_on_book")

# %% [markdown]
# # Total_Relationship_Count

# %%
cat_chart("Total_Relationship_Count")

# %% [markdown]
# # Months_Inactive_12_mon

# %%
cat_chart("Months_Inactive_12_mon")

# %% [markdown]
# # Contacts_Count_12_mon

# %%
cat_chart("Contacts_Count_12_mon")

# %%
#numerical

# %%
info_num("Customer_Age")
# Out:
# Customer_Age
# Mean: 47.285276982324476
# Median: 46.0
# Mode 44
# Standard deviation: 13.270923260536502
# Minimum value: 26
# Maximum value: 222
# Missing value: 0

# %%
df["Customer_Age"]
# Out:
# 0        45
# 1        49
# 2        51
# 3        40
# 4        40
#          ..
# 10122    50
# 10123    41
# 10124    44
# 10125    30
# 10126    43
# Name: Customer_Age, Length: 10127, dtype: int64

# %%
def num_charts(col):
    fig, ax = plt.subplots(1,2, figsize=(15,8))
    sns.histplot(df[col], ax = ax[0], color= "m")
    sns.boxplot(df[col], ax = ax[1], color= "m")
    plt.show()

# %%
num_charts("Customer_Age")

# %% [markdown]
# # Outlier treatment

# %%
Q1 = df["Customer_Age"].quantile(.25)
Q3 = df["Customer_Age"].quantile(.75)

IQR= Q3-Q1

# %%
LF = Q1-1.5*IQR
UF = Q3+1.5*IQR
print("lower fence=",LF)
print("Upper fence=",UF)
# Out:
# lower fence= 24.5
# Upper fence= 68.5

# %%
x=df[(df["Customer_Age"]>UF) | (df["Customer_Age"]<LF)]
index_out = x.index
index_out
# Out:
# Index([  60,   72,  160,  198,  251,  254,  323,  366,  389,  431,  544,  602,
#         702,  893,  923, 1220, 1249, 1364, 1463, 1583, 1642, 1687, 1759, 1788,
#        2169, 2272, 2293, 2312, 2347, 2395, 2529, 2690, 2731, 3089, 3317, 3667,
#        3770, 3943, 4062, 4067, 4346, 4460, 4471, 4472, 4518, 4519, 4540, 4549,
#        4579, 5118, 5151, 5340, 5676, 5848, 5881, 5897, 5927, 5957, 6205, 6693,
#        6757, 6773, 6990, 7009, 7032, 7074, 7076, 7100, 7163, 7262, 7297, 7385,
#        7542, 7644, 7764, 7771, 7806, 7915, 7931, 8222, 8451, 8543, 8619, 8667,
#        8802, 9054, 9295, 9407, 9469, 9473, 9475, 9527, 9534, 9619, 9736, 9778,
#        9809, 9871, 9888],
#       dtype='int64')

# %%
for i in index_out:
    df.loc[i, "Customer_Age"]= df["Customer_Age"].median()             #replacing the outlier with median value

# %%
df.loc[160, "Customer_Age"]     #example
# Out:
# 46

# %%
#after outlier treatment
num_charts("Customer_Age")

# %% [markdown]
# # Credit_Limit

# %%
df["Credit_Limit"].isnull().sum()
# Out:
# 60

# %%
df["Credit_Limit"].fillna(df["Credit_Limit"].mean(), inplace=True)      #it is a numerical value we are replacing it with mean

# %%
df["Credit_Limit"].isnull().sum()
# Out:
# 0

# %%
info_num("Credit_Limit")
# Out:
# Credit_Limit
# Mean: 8703.180550312904
# Median: 4597.0
# Mode 34516.0
# Standard deviation: 9162.791334473803
# Minimum value: 1438.3
# Maximum value: 34664.0
# Missing value: 0

# %%
num_charts("Credit_Limit")       #It contains outliers

# %%
Q1 = df["Credit_Limit"].quantile(.25)
Q3 = df["Credit_Limit"].quantile(.75)

IQR= Q3-Q1

# %%
LF = Q1-1.5*IQR
UF = Q3+1.5*IQR
print("lower fence=",LF)
print("Upper fence=",UF)
# Out:
# lower fence= -10214.75
# Upper fence= 23859.25

# %%
y=df[(df["Credit_Limit"]>UF) | (df["Credit_Limit"]<LF)]
index_out1 = y.index
index_out1
# Out:
# Index([    6,     7,    16,    40,    45,    61,    63,    65,    69,    70,
#        ...
#        10079, 10086, 10088, 10095, 10098, 10100, 10104, 10110, 10111, 10112],
#       dtype='int64', length=1008)

# %%
y
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 6      810347208  Existing Customer            51      M                4
# 7      818906208  Existing Customer            32      M                0
# 16     709967358  Existing Customer            48      M                4
# 40     827111283  Existing Customer            45      M                3
# 45     712661433  Existing Customer            49      M                4
# ...          ...                ...           ...    ...              ...
# 10100  719848008  Existing Customer            39      M                2
# 10104  715474083  Existing Customer            51      M                3
# 10110  718225683  Existing Customer            56      M                1
# 10111  710734308  Existing Customer            49      M              113
# 10112  708564858  Attrited Customer            33      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
for i in index_out1:                    #outlier treatment method
    df.loc[i, "Credit_Limit"]= df["Credit_Limit"].median()               #median is least affected by outliers

# %%
num_charts("Credit_Limit")

# %% [markdown]
# # There are more customers with credit limit below 5000 and the distribution of credit limit is right skewed thereby having higher number of lower values

# %% [markdown]
# # Total_Revolving_Bal

# %%
info_num("Total_Revolving_Bal")
# Out:
# Total_Revolving_Bal
# Mean: 1162.8140614199665
# Median: 1276.0
# Mode 0
# Standard deviation: 814.9873352357697
# Minimum value: 0
# Maximum value: 2517
# Missing value: 0

# %%
#separating out the categorical and continuous variables

def seperate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:
        if df[column].nunique() < 100:
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous

categorical, continuous = seperate_data_types(df)

#Tabulate is a package used to print the list, dict or any data sets in a proper format; in a table format

from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical, "Continuous":continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical               continuous
# ------------------------  ---------------------
# Attrition_Flag            CLIENTNUM
# Customer_Age              Credit_Limit
# Gender                    Total_Revolving_Bal
# Dependent_count           Avg_Open_To_Buy
# Education_Level           Total_Trans_Amt
# Marital_Status            Total_Trans_Ct
# Income_Category           Avg_Utilization_Ratio
# Card_Category
# Months_on_book
# Total_Relationship_Count
# Months_Inactive_12_mon
# Contacts_Count_12_mon

# %%
#cat_cat_analysis         #we will make bar chart for this

# %% [markdown]
# # Level 2

# %%
fig, ax=plt.subplots(figsize=(15,8))
sns.countplot(x="Gender", hue = "Attrition_Flag", data=df)     #countplot
plt.show()

# %%
def cat_cat_analysis(col1,col2):
    fig, ax=plt.subplots(figsize=(15,8))
    sns.countplot(x=col1, hue = col2, data=df)
    plt.show()

# %%
cat_cat_analysis("Gender", "Attrition_Flag")

# %%
cat_cat_analysis("Card_Category", "Attrition_Flag")

# %%
#cat_num_analysis

# %%
df.groupby("Attrition_Flag")[["Credit_Limit"]].sum()
# Out:
#                    Credit_Limit
# Attrition_Flag
# Attrited Customer  8.953958e+06
# Existing Customer  5.191781e+07

# %%
x= df.groupby("Attrition_Flag")[["Credit_Limit"]].mean()

# %%
import numpy as np
def cat_num_analysis(cat, num):
    x=df.groupby(cat)[num].mean()
    fig, ax=plt.subplots(2,2, figsize=(15,10))
    sns.histplot(x= df[num], hue=df[cat], ax=ax[0,0])
    sns.boxplot(y= df[num], x=df[cat], ax=ax[0,1])
    sns.barplot(x= cat, y=num, data= df, estimator=np.mean, ax=ax[1,0])
    ax[1,1].pie(x, labels=x.index, autopct= "%0.2f%%")
    plt.show()

# %%
cat_num_analysis("Attrition_Flag", "Credit_Limit")

# %%
#num_num_analysis

# %%
def num_num(num1, num2):
    plt.scatter(df[num1], df[num2])
    plt.title(num1+ "vs" + num2 )                                                    #stringwise concatination
    plt.xlabel(num1 + "   correlation value = "+str(df[num1].corr(df[num2])))         #stringwise concatination
    plt.ylabel(num2)
    plt.show()

# %%
num_num("Credit_Limit","Avg_Utilization_Ratio" )

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# # level 3

# %%
#for attrited customer how is the genderwise age distribution
# attributed_flag --- attrited customer 
#gender
#age

# %%
attrited_data = df[(df["Attrition_Flag"]=="Attrited Customer")]    #this data is for attrited customers only
attrited_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 21     708508758  Attrited Customer            62      F                0
# 39     708300483  Attrited Customer            66      F                0
# 51     779471883  Attrited Customer            54      F                1
# 54     714374133  Attrited Customer            56      M                2
# 61     712030833  Attrited Customer            48      M                2
# ...          ...                ...           ...    ...              ...
# 10119  716893683  Attrited Customer            55      F                3
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
def cat_num_analysis_level3(cat, num):
    x=attrited_data.groupby(cat)[num].mean()
    fig, ax=plt.subplots(2,2, figsize=(15,10))
    sns.histplot(x= attrited_data[num], hue=attrited_data[cat], ax=ax[0,0])
    sns.boxplot(y= attrited_data[num], x=attrited_data[cat], ax=ax[0,1])
    sns.barplot(x= cat, y=num, data= attrited_data, estimator=np.mean, ax=ax[1,0])
    ax[1,1].pie(x, labels=x.index, autopct= "%0.2f%%")
    plt.show()

# %%
cat_num_analysis_level3("Gender","Customer_Age")
