# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv("DS1_C4_S4_Test_Scores_Data_Practice.csv")

# %%
dataframe
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
#Task 1

# %%
dataframe.isnull().sum()
# Out:
# school                0
# school_setting        0
# school_type           0
# classroom             0
# teaching_method       0
# student_id            0
# gender               10
# tuitionfee_waiver     0
# test1                 4
# test2                 4
# dtype: int64

# %%
mean_test1 = dataframe["test1"].mean()
mean_test1
# Out:
# 54.96195396899953

# %%
dataframe['test1'].value_counts()
# Out:
# test1
# 60.0    73
# 63.0    63
# 58.0    63
# 59.0    61
# 62.0    60
#         ..
# 88.0     1
# 23.0     1
# 91.0     1
# 22.0     1
# 25.0     1
# Name: count, Length: 69, dtype: int64

# %%
dataframe['test1'].fillna(mean_test1, inplace=True)     #replacing missing values with mean

# %%
dataframe.isnull().sum()          #mean added for test1
# Out:
# school                0
# school_setting        0
# school_type           0
# classroom             0
# teaching_method       0
# student_id            0
# gender               10
# tuitionfee_waiver     0
# test1                 0
# test2                 4
# dtype: int64

# %%
dataframe['test2'].value_counts()
# Out:
# test2
# 69.0    65
# 70.0    61
# 72.0    60
# 68.0    58
# 79.0    57
#         ..
# 37.0     3
# 36.0     2
# 34.0     1
# 35.0     1
# 32.0     1
# Name: count, Length: 68, dtype: int64

# %%
median_test2 = dataframe["test2"].median()
median_test2
# Out:
# 68.0

# %%
dataframe["test2"].fillna(median_test2, inplace=True)     #replacing missing values with median of test2

# %%
dataframe.isnull().sum()
# Out:
# school                0
# school_setting        0
# school_type           0
# classroom             0
# teaching_method       0
# student_id            0
# gender               10
# tuitionfee_waiver     0
# test1                 0
# test2                 0
# dtype: int64

# %%
#task2 
#identify and display the duplicate rows and delete the duplicate rows in the data

# %%
df1 = dataframe.loc[:,dataframe.columns !='student_id']
df1
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# ...     ...            ...         ...       ...             ...     ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
df1[df1.duplicated(keep = "first")]
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# 19    ANKYI          Urban  Non-public       6OL        Standard    Male
# 38    ANKYI          Urban  Non-public       ZNS        Standard  Female
# 50    CCAAW       Suburban  Non-public       2B1    Experimental    Male
# 106   CCAAW       Suburban  Non-public       PGK        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2058  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2067  ZOWMK          Urban      Public       Q0E    Experimental    Male
# 2070  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2080  ZOWMK          Urban      Public       QA2        Standard  Female
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
df1_dropped_duplicates = df1.drop_duplicates(keep= "first")
df1_dropped_duplicates
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 2     ANKYI          Urban  Non-public       6OL        Standard    Male
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 5     ANKYI          Urban  Non-public       6OL        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
df1_dropped_duplicates = df1.drop_duplicates(keep= "last")
df1_dropped_duplicates
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 0     ANKYI          Urban  Non-public       6OL        Standard  Female
# 1     ANKYI          Urban  Non-public       6OL        Standard  Female
# 3     ANKYI          Urban  Non-public       6OL        Standard  Female
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# 5     ANKYI          Urban  Non-public       6OL        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2129  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2130  ZOWMK          Urban      Public       ZBH        Standard  Female
# 2131  ZOWMK          Urban      Public       ZBH        Standard    Male
# 2132  ZOWMK          Urban      Public       ZBH        Standard    Male
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
df1[df1.duplicated(keep = "first")]
# Out:
#      school school_setting school_type classroom teaching_method  gender  \
# 4     ANKYI          Urban  Non-public       6OL        Standard    Male
# 19    ANKYI          Urban  Non-public       6OL        Standard    Male
# 38    ANKYI          Urban  Non-public       ZNS        Standard  Female
# 50    CCAAW       Suburban  Non-public       2B1    Experimental    Male
# 106   CCAAW       Suburban  Non-public       PGK        Standard  Female
# ...     ...            ...         ...       ...             ...     ...
# 2058  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2067  ZOWMK          Urban      Public       Q0E    Experimental    Male
# 2070  ZOWMK          Urban      Public       Q0E    Experimental  Female
# 2080  ZOWMK          Urban      Public       QA2        Standard  Female
# 2128  ZOWMK          Urban      Public       ZBH        Standard  Female
#
#                 tuitionfee_waiver  test1  test2
# ...

# %%
dataframe_dropped_duplicates_byCol = dataframe.drop_duplicates(['school', "school_setting", "school_type", "classroom", "teaching_method", "gender", "tuitionfee_waiver", "test1", "test2"], keep = "first")
dataframe_dropped_duplicates_byCol
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 5     ANKYI          Urban  Non-public       6OL        Standard      7YZO8
# ...     ...            ...         ...       ...             ...        ...
# 2127  ZOWMK          Urban      Public       ZBH        Standard      S4I5S
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %% [markdown]
# Task 3
# In the column named 'tuitionfee_waiver', replace the value Does not qualify' and 'Qualifies for reduced/free' with No and Yes, respectively. Display the updated column data and verify if the values are replaced.

# %%
dataframe
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender            tuitionfee_waiver  test1  test2
# ...

# %%
dataframe.replace(to_replace = ["Does not qualify","Qualifies for reduced/free "], value=["No","Yes"],inplace = True)
dataframe
# Out:
#      school school_setting school_type classroom teaching_method student_id  \
# 0     ANKYI          Urban  Non-public       6OL        Standard      2FHT3
# 1     ANKYI          Urban  Non-public       6OL        Standard      3JIVH
# 2     ANKYI          Urban  Non-public       6OL        Standard      3XOWE
# 3     ANKYI          Urban  Non-public       6OL        Standard      556O0
# 4     ANKYI          Urban  Non-public       6OL        Standard      74LOE
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard      T8LSK
# 2129  ZOWMK          Urban      Public       ZBH        Standard      VNP26
# 2130  ZOWMK          Urban      Public       ZBH        Standard      YDR1Z
# 2131  ZOWMK          Urban      Public       ZBH        Standard      YUEIH
# 2132  ZOWMK          Urban      Public       ZBH        Standard      ZVCQ8
#
#       gender tuitionfee_waiver  test1  test2
# ...

# %%
#doubt in 3

# %% [markdown]
# Task 4
# Calculate and display the average of test scores of students at each school. Display the name of the school that has the highest average test score.
# Hint: Use the "group by" operation to first segregate the data for each school and then calculate the average test score.

# %%
avg_test1_scores=dataframe.groupby(by = ["school"])["test1"].mean()
avg_test1_scores
# Out:
# school
# ANKYI    61.341463
# CCAAW    64.623853
# CIMBB    65.067568
# CUQAM    53.925234
# DNQDD    54.327869
# FBUMG    62.891304
# GJJHK    53.194915
# GOKXL    50.796875
# GOOBU    38.354190
# IDGFP    75.202128
# KFZMY    41.865385
# KZKKE    37.261261
# LAYPA    62.035088
# OJOBU    56.197531
# QOQTS    52.543369
# UAGPU    62.390805
# UKPGS    78.453125
# UUUQX    67.106690
# VHDHF    52.666667
# VKWQH    52.060000
# VVTVA    36.122473
# ZMNYA    68.130435
# ZOWMK    41.572650
# Name: test1, dtype: float64

# %%
print("The name of the school that has the highest average test score.")
avg_test1_scores.sort_values(ascending = False)[:1]
# Out:
# The name of the school that has the highest average test score.
# school
# UKPGS    78.453125
# Name: test1, dtype: float64

# %% [markdown]
# Task 5
# Display the highest test2 score of each school in a tabular format.
# Display the name of the top five schools based on the output of the above task.
# Hint: Use the pivot table function

# %%
pivot_tab = pd.pivot_table(dataframe, index = ["school"], values = ["test2"], aggfunc = "max")
pivot_tab.sort_values(by = "test2" ,ascending = False)[:5]
# Out:
#         test2
# school
# IDGFP   100.0
# UKPGS    99.0
# ZMNYA    95.0
# CCAAW    91.0
# UUUQX    91.0

# %% [markdown]
# Task 6
# The school named 'FBUMG' is offering a scholarship of $500 for the students of class '5LQ' who have scored>=80 in test2.
# Display the information of these students along with student_ID and scholarship amounts in a tabular format.
# Hint: Use the concat operation to append a new column to your data frame. The scholarship column will have to be populated as a series, prior to using it in the concat operation.

# %%
df = dataframe[(dataframe["school"]=="FBUMG") & (dataframe["classroom"]=="5LQ") &  (dataframe['test2'] >= 80)]
df["scholarship"]=500
df
# Out:
# C:\Users\rasto\AppData\Local\Temp\ipykernel_12600\3186232879.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["scholarship"]=500
#     school school_setting school_type classroom teaching_method student_id  \
# 467  FBUMG          Rural  Non-public       5LQ    Experimental      04DG5
# 468  FBUMG          Rural  Non-public       5LQ    Experimental      20M2D
# 469  FBUMG          Rural  Non-public       5LQ    Experimental      39KCW
# 470  FBUMG          Rural  Non-public       5LQ    Experimental      5Z1B6
# 471  FBUMG          Rural  Non-public       5LQ    Experimental      6TLU8
# 472  FBUMG          Rural  Non-public       5LQ    Experimental      ATQQJ
# ...

# %% [markdown]
# Task 7
# Display the count of each type of teaching method, segregated by school setting.

# %%
#use cross table
g =pd.crosstab(index = dataframe["school_setting"], columns = dataframe["teaching_method"])
g
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     201       309
# Suburban                  284       433
# Urban                     275       631

# %%
pd.crosstab(dataframe.school_setting, dataframe.teaching_method, rownames= ["school_setting"], colnames = ["teaching_method"])
# Out:
# teaching_method  Experimental  Standard
# school_setting
# Rural                     201       309
# Suburban                  284       433
# Urban                     275       631

# %%
pd.pivot_table(dataframe, index = ["school_setting"] , values = ["teaching_method"], aggfunc = "count")
# Out:
#                 teaching_method
# school_setting
# Rural                       510
# Suburban                    717
# Urban                       906

# %% [markdown]
# Task 8
# Display the gender-wise count of students in different school settings - rural, suburban, and urban.
# Hint: Use the "group by" operation on school setting and gender and then use the "count"operation

# %%
genderwise_count = dataframe.groupby(by= ["gender"])["school_setting"].value_counts()
genderwise_count
# Out:
# gender  school_setting
# Female  Urban             456
#         Suburban          368
#         Rural             228
# Male    Urban             444
#         Suburban          348
#         Rural             279
# Name: count, dtype: int64

# %%
genderwise_count2 = dataframe.groupby(["gender","school_setting"]).count()
genderwise_count2
# Out:
#                        school  school_type  classroom  teaching_method  \
# gender school_setting
# Female Rural              228          228        228              228
#        Suburban           368          368        368              368
#        Urban              456          456        456              456
# Male   Rural              279          279        279              279
#        Suburban           348          348        348              348
#        Urban              444          444        444              444
#
#                        student_id  tuitionfee_waiver  test1  test2
# gender school_setting
# Female Rural                  228                228    228    227
#        Suburban               368                368    368    367
#        Urban                  456                456    454    454
# Male   Rural                  279                279    279    279
#        Suburban               348                348    347    348
# ...

# %% [markdown]
# Task 9
# Display the average test2 scores of male and female students from each school setting.

# %%
dataframe.groupby(by= ["gender","school_setting"])["test2"].mean()
# Out:
# gender  school_setting
# Female  Rural             63.973568
#         Suburban          76.049046
#         Urban             61.149780
# Male    Rural             64.032258
#         Suburban          75.942529
#         Urban             62.421171
# Name: test2, dtype: float64
