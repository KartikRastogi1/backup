# %% [markdown]
# Create a shopping cart with the following basic functionality:
# - Display the list of items available in the store, along with the corresponding quantities currently in stock and the cost per item.
# - Ask the customer to enter the number of quantities required for each item.
# - Display a message if the item is out of stock.
# - Accept customer name and delivery address as the input.
#
# delivery charges based on the distance of the delivery address from the store, as shown below:
# - $10 for up to 5 miles.
# - $12 between 5-10 miles
# - $14 between 10-15 miles $20 for beyond 15 miles
# Display the final bill with the items purchased and the customer details.

# %%
d1 = {'Item 1':('Chocolate', 15, 5),
      'Item 2':('Rice 2 Pounds', 5, 50),
      'Item 3':('Oreo', 20, 15),
      'Item 4':('Cheese 250g', 25, 30),
      'Item 5':('maggie', 25, 15),
      'Item 6':('Oats 4  Pounds', 5, 5),
      'Item 7':('Cereals 1 Pound', 10, 20),
      'Item 8':('Ice Cream 1 Pound', 1, 10)}

# %%
type(d1)
# Out:
# dict

# %%
def shopping_cart(d1):
    print(     "                           ", "Items Available" )
    print("")
    print("Sno     Items           Quantity     Price")
    print("1       "   +str(d1["Item 1"][0])+    "               "  +  str(d1['Item 1'][1]) + "         "+ str(d1['Item 1'][2]))                 
    print("2       "   +str(d1["Item 2"][0])+    "          "  +  str(d1['Item 2'][1]) + "         "+ str(d1['Item 2'][2]))   
    print("3       "   +str(d1["Item 3"][0])+    "                  "  +  str(d1['Item 3'][1]) + "         "+ str(d1['Item 3'][2]))     
    print("4       "   +str(d1["Item 4"][0])+    "           "  +  str(d1['Item 4'][1]) + "         "+ str(d1['Item 4'][2]))  
    print("5       "   +str(d1["Item 5"][0])+    "                "  +  str(d1['Item 5'][1]) + "         "+ str(d1['Item 5'][2]))  
    print("6       "   +str(d1["Item 6"][0])+    "         "  +  str(d1['Item 6'][1]) + "          "+ str(d1['Item 6'][2]))  
    print("7       "   +str(d1["Item 7"][0])+    "       "  +  str(d1['Item 7'][1]) + "         "+ str(d1['Item 7'][2]))  
    print("8       "   +str(d1["Item 8"][0])+    "         "  +  str(d1['Item 8'][1]) + "      "+ str(d1['Item 8'][2]))  
    print("********************************************************** ")
    
    print(" ")
    quant_1 = int(input("Enter the number of Chocolate required:   "))
    quant_2 = int(input("Enter the number of Rice required:   "))
    quant_3 = int(input("Enter the number of Oreo required:   "))
    quant_4=  int(input("Enter the number of Cheese required:   "))
    quant_5 = int(input("Enter the number of Maggie required:   "))
    quant_6 = int(input("Enter the number of Oats required:   "))
    quant_7 = int(input("Enter the number of Cereals required:   "))
    quant_8 = int(input("Enter the number of Ice cream required:   "))
    
    if (
    quant_1 <=d1['Item 1'][1] and
    quant_2 <=d1['Item 1'][1] and
    quant_3 <=d1['Item 1'][1] and
    quant_4 <=d1['Item 1'][1] and
    quant_5 <=d1['Item 1'][1] and
    quant_6 <=d1['Item 1'][1] and
    quant_7 <=d1['Item 1'][1] and
    quant_8 <=d1['Item 1'][1]):
        
        
        
        total_price = (
            quant_1*d1['Item 1'][2]+
            quant_2*d1['Item 2'][2]+
            quant_3*d1['Item 3'][2]+
            quant_4*d1['Item 4'][2]+
            quant_5*d1['Item 5'][2]+
            quant_6*d1['Item 6'][2]+
            quant_7*d1['Item 7'][2]+
            quant_8*d1['Item 8'][2])
        print("   ")
        print("Total Bill: ",total_price)
        print("   ")
        print("Fill in your delivery details")
        input("Enter your name:  ")
        input("Enter your address:  ")
        a=int(input("Distance from the shop (0-5),(6-10),(11-15) and (above 15):  "))
        
        if a<=5:
            print("Sno     Items           Quantity     Price")
            print("1       "   +str(d1["Item 1"][0])+    "               "  +  str(quant_1) + "         "+ str(quant_1*d1['Item 1'][2]))                 
            print("2       "   +str(d1["Item 2"][0])+    "             "  +  str(quant_2) + "       "+ str(quant_2*d1['Item 2'][2]))
            print("3       "   +str(d1["Item 3"][0])+    "                  "  +  str(quant_3) + "             "+ str(quant_3*d1['Item 3'][2]))
            print("4       "   +str(d1["Item 4"][0])+    "            "  +  str(quant_4) + "         "+ str(quant_4*d1['Item 4'][2]))
            print("5       "   +str(d1["Item 5"][0])+    "               "  +  str(quant_5) + "         "+ str(quant_5*d1['Item 5'][2]))
            print("6       "   +str(d1["Item 6"][0])+    "               "  +  str(quant_6) + "         "+ str(quant_6*d1['Item 6'][2]))
            print("7       "   +str(d1["Item 7"][0])+    "               "  +  str(quant_7) + "         "+ str(quant_7*d1['Item 7'][2]))
            print("8       "   +str(d1["Item 8"][0])+    "               "  +  str(quant_8) + "         "+ str(quant_8*d1['Item 8'][2]))
            print("    ")
            print("Total Bill: ",total_price+10)
         
        elif a>=6 and a<=10:
            print("Sno     Items           Quantity     Price")
            print("1       "   +str(d1["Item 1"][0])+    "               "  +  str(quant_1) + "         "+ str(quant_1*d1['Item 1'][2]))                 
            print("2       "   +str(d1["Item 2"][0])+    "            "  +  str(quant_2) + "         "+ str(quant_2*d1['Item 2'][2]))
            print("3       "   +str(d1["Item 3"][0])+    "                  "  +  str(quant_3) + "         "+ str(quant_3*d1['Item 3'][2]))
            print("4       "   +str(d1["Item 4"][0])+    "             "  +  str(quant_4) + "         "+ str(quant_4*d1['Item 4'][2]))
            print("5       "   +str(d1["Item 5"][0])+    "            "  +  str(quant_5) + "         "+ str(quant_5*d1['Item 5'][2]))
            print("6       "   +str(d1["Item 6"][0])+    "                  "  +  str(quant_6) + "         "+ str(quant_6*d1['Item 6'][2]))
            print("7       "   +str(d1["Item 7"][0])+    "            "  +  str(quant_7) + "         "+ str(quant_7*d1['Item 7'][2]))
            print("8       "   +str(d1["Item 8"][0])+    "                  "  +  str(quant_8) + "         "+ str(quant_8*d1['Item 8'][2]))
            print("    ")
            print("Total Bill: ",total_price+12)
        elif a>=11 and a<=15:
            print("Sno     Items           Quantity     Price")
            print("1       "   +str(d1["Item 1"][0])+    "               "  +  str(quant_1) + "         "+ str(quant_1*d1['Item 1'][2]))                 
            print("2       "   +str(d1["Item 2"][0])+    "               "  +  str(quant_2) + "         "+ str(quant_2*d1['Item 2'][2]))
            print("3       "   +str(d1["Item 3"][0])+    "               "  +  str(quant_3) + "         "+ str(quant_3*d1['Item 3'][2]))
            print("4       "   +str(d1["Item 4"][0])+    "               "  +  str(quant_4) + "         "+ str(quant_4*d1['Item 4'][2]))
            print("5       "   +str(d1["Item 5"][0])+    "               "  +  str(quant_5) + "         "+ str(quant_5*d1['Item 5'][2]))
            print("6       "   +str(d1["Item 6"][0])+    "               "  +  str(quant_6) + "         "+ str(quant_6*d1['Item 6'][2]))
            print("7       "   +str(d1["Item 7"][0])+    "               "  +  str(quant_7) + "         "+ str(quant_7*d1['Item 7'][2]))
            print("8       "   +str(d1["Item 8"][0])+    "               "  +  str(quant_8) + "         "+ str(quant_8*d1['Item 8'][2]))
            print("    ")
            print("Total Bill: ",total_price+15)
        else:
            print("Sno     Items           Quantity     Price")
            print("1       "   +str(d1["Item 1"][0])+    "               "  +  str(quant_1) + "         "+ str(quant_1*d1['Item 1'][2]))                 
            print("2       "   +str(d1["Item 2"][0])+    "               "  +  str(quant_2) + "         "+ str(quant_2*d1['Item 2'][2]))
            print("3       "   +str(d1["Item 3"][0])+    "               "  +  str(quant_3) + "         "+ str(quant_3*d1['Item 3'][2]))
            print("4       "   +str(d1["Item 4"][0])+    "               "  +  str(quant_4) + "         "+ str(quant_4*d1['Item 4'][2]))
            print("5       "   +str(d1["Item 5"][0])+    "               "  +  str(quant_5) + "         "+ str(quant_5*d1['Item 5'][2]))
            print("6       "   +str(d1["Item 6"][0])+    "               "  +  str(quant_6) + "         "+ str(quant_6*d1['Item 6'][2]))
            print("7       "   +str(d1["Item 7"][0])+    "               "  +  str(quant_7) + "         "+ str(quant_7*d1['Item 7'][2]))
            print("8       "   +str(d1["Item 8"][0])+    "               "  +  str(quant_8) + "         "+ str(quant_8*d1['Item 8'][2]))
            print("    ")
            print("Total Bill: ",total_price+20)
        
        print("Do you want to continue shopping:  ")
        print("  ")
        print("  ")
        x=input("yes/no: ")
        if x.lower()=='yes':
            d2 = {'Item 1':('kit kat', d1['Item 1'][1] - quant_1, 5),
                        'Item 2':('Rice 2 Pounds', d1['Item 2'][1] - quant_2, 50),
                        'Item 3':('Oreo', d1['Item 3'][1] - quant_3, 15),
                        'Item 4':('Panner 250g', d1['Item 4'][1] - quant_4, 30),
                        'Item 5':('maggie', d1['Item 5'][1] - quant_5, 15),
                        'Item 6':('Oats 4  Pounds', d1['Item 6'][1] - quant_6, 5),
                        'Item 7':('Cereals 1 Pound', d1['Item 7'][1] - quant_7, 20),
                        'Item 8':('Daal 1 Pound', d1['Item 8'][1] - quant_8, 10)}
            shopping_cart(d2)
            
        elif x.lower()=='no':
            print("Thanks for shopping with us:  ")
    else:
        print(" ")
        print("Sorry! Item is out of stock.  Please check the quantity again")
            
        
        
        
    
    
    
    
    
    
    
shopping_cart(d1)
# Out:
#                             Items Available
#
# Sno     Items           Quantity     Price
# 1       Chocolate               15         5
# 2       Rice 2 Pounds          5         50
# 3       Oreo                  20         15
# 4       Cheese 250g           25         30
# 5       maggie                25         15
# 6       Oats 4  Pounds         5          5
# 7       Cereals 1 Pound       10         20
# 8       Ice Cream 1 Pound         1      10
# **********************************************************
#
# Enter the number of Chocolate required:   1
# Enter the number of Rice required:   1
# Enter the number of Oreo required:   1
# Enter the number of Cheese required:   1
# Enter the number of Maggie required:   1
# Enter the number of Oats required:   1
# Enter the number of Cereals required:   1
# Enter the number of Ice cream required:   1
#
# Total Bill:  150
#
# Fill in your delivery details
# Enter your name:  kartik
# Enter your address:  dsjdbs
# ...
