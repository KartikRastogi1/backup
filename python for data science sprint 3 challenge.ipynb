# %%
import numpy as np
import pandas as pd

# %%
#task1

# %%
df = pd.read_csv("DS1_C4_S3_Loan_Data_Challenge.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    int64
#  9   Loan_Amount_Term   614 non-null    int64
#  10  Credit_History     614 non-null    int64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 62.5+ KB

# %%
#task 2
#display the list of female who are self-employed and have an income greater than $4,000

# %%
condition= (df["Gender"]=="Female") & (df["Self_Employed"]=="Yes") & (df["ApplicantIncome"]>4000)

# %%
condition
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613     True
# Length: 614, dtype: bool

# %%
female_income =df[condition]

# %%
female_income
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %% [markdown]
# Task 3
# Identify those male customers who hold a graduate degree and have the loan status as 'Y' (yes).
# • Display the information of these customers.
# • Display the count of these customers.

# %%
condition2 = (df["Gender"]=="Male") & (df["Education"]=="Graduate") & (df["Loan_Status"]=="Y")

# %%
male_details=df[condition2]

# %%
print("Information of the customers")
male_details
# Out:
# Information of the customers
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
print("count of these customers is",len(male_details))
# Out:
# count of these customers is 279

# %% [markdown]
# Task 4
# Calculate the number of customers who have the loan status as
# "Y", three or more dependents, and a property in rural area. Display all the details of such customers.
# Note: Do not use any additional data frame to store the results.

# %%
condition3 = (df["Loan_Status"]=="Y") & (df["Dependents"]=="3+") & (df["Property_Area"]=="Rural")

# %%
x = condition3

# %%
df[x]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %% [markdown]
# Task 5
# A new customer, Warner Kim, has applied for a loan of $290,000. Warner Kim is a graduate and owns a property in an urban area.
# Check whether Warner Kim would get his loan approved or not

# %%
condition4 = (df["Education"]=="Graduate") & (df['Property_Area']=="Urban")

# %%
condition4
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 609    False
# 610    False
# 611     True
# 612     True
# 613    False
# Length: 614, dtype: bool

# %%
df[condition4]["Loan_Status"]
# Out:
# 0      Y
# 2      Y
# 4      Y
# 5      Y
# 8      Y
#       ..
# 599    Y
# 600    N
# 602    Y
# 611    Y
# 612    Y
# Name: Loan_Status, Length: 162, dtype: object

# %% [markdown]
# Task 6
# Identify the customers who are not married, are self-employed, live in a non-urban area, and have their loan status as 'N'.
# Calculate and display the gender-wise count of such customers.

# %%
condtion5 = (df["Married"]=="No") & (df["Self_Employed"]=="Yes") & (df["Property_Area"]=="Rural")

# %%
df[condtion5]["Gender"].value_counts()
# Out:
# Gender
# Male      7
# Female    1
# Name: count, dtype: int64

# %% [markdown]
# Task 7
# Calculate and display the average income of customers based on each area where their property is located; (urban, semiurban, rural).

# %%
Urban  = df["Property_Area"]=="Urban"

# %%
urban_avg_income = df[Urban]["ApplicantIncome"].mean()

# %%
print("Average income of customers based on Urban is",urban_avg_income)
# Out:
# Average income of customers based on Urban is 5398.247524752475

# %%
semiurban  = df["Property_Area"]=="Semiurban"

# %%
semiurban_avg_income = df[semiurban]['ApplicantIncome'].mean()
print("Average income of customers based on semi-urban is",semiurban_avg_income)
# Out:
# Average income of customers based on semi-urban is 5292.261802575107

# %%
rural  = df["Property_Area"]=="Rural"

# %%
rural_avg_income = df[rural]["ApplicantIncome"].mean()
print("Average income of customers based on rural property is",rural_avg_income)
# Out:
# Average income of customers based on rural property is 5554.083798882682

# %% [markdown]
# Task 8
# List the customers who have a property in a rural or semiurban area, applicant's income > $4,000, co-applicant's income
# >$1,000, and loan status is 'N'. Count the number of such customers.
# • Update the loan status of such customers to 'Y'.
# • Redo the same task to verify that the count of such customers is now zero (after updating the loan status to 'Y').

# %%
condition6 = ((df["Property_Area"] == "Rural") | (df["Property_Area"] == "Semiurban")) & (df["ApplicantIncome"] > 4000) & (df["CoapplicantIncome"] > 1000) & (df["Loan_Status"]=="N")
df[condition6]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# ...

# %%
count_before_update = len(condition6)

# %%
count_before_update
# Out:
# 614

# %%
df.loc[condition6.index, 'loan_status'] = 'Y'

# %%
condition6_after_update = df[
    (df['Property_Area'].isin(['Rural', 'Semiurban'])) &
    (df['ApplicantIncome'] > 4000) &
    (df['CoapplicantIncome'] > 1000) &
    (df['Loan_Status'] == 'N')]

# %%
count_after_update = len(condition6_after_update)
count_after_update
# Out:
# 23

# %% [markdown]
# Task 9
# Display the average income and the count of customers who have 3+ dependents, live in an urban area, and have their loan status as 'Y'.

# %%
condition7 =  (df["Dependents"]=="3+") & (df["Property_Area"]=="Urban") & (df["Loan_Status"]=="Y")
df[condition7]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 61   LP001206   Male     Yes         3+      Graduate            No
# 68   LP001238   Male     Yes         3+  Not Graduate           Yes
# 171  LP001585   Male     Yes         3+      Graduate            No
# 267  LP001882   Male     Yes         3+      Graduate            No
# 295  LP001949   Male     Yes         3+      Graduate            No
# 461  LP002484   Male     Yes         3+      Graduate            No
# 531  LP002720   Male     Yes         3+      Graduate            No
# 602  LP002953   Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 61              3029                0.0          99               360
# 68              7100                0.0         125                60
# 171            51763                0.0         700               300
# 267             4333             1811.0         160               360
# ...

# %%
average = df[condition7]["ApplicantIncome"].mean()
print("Average income is",average)
# Out:
# Average income is 11045.625

# %%
print("Count of the customers is",len(df[condition7]))
# Out:
# Count of the customers is 8

# %% [markdown]
# Task 10:
# Display the list of customers who live in rural or semiurban areas, with 3+ dependents, and have their income greater than the average income of the customers who live in an urban area.
# • What do you infer from this task? Can you infer an important parameter that the bank is using to approve loans?
# • Display the average applicant income of those customers who are from non-urban areas and have their loan status as 'Y'.

# %%
urban_area = df[(df["Property_Area"]=="Urban")]["ApplicantIncome"].mean()

# %%
print("average income of the customers who live in an urban area.",urban_area)
# Out:
# average income of the customers who live in an urban area. 5398.247524752475

# %%
condition8 = ((df["Property_Area"] == "Rural") | (df["Property_Area"] == "Semiurban")) & (df["Dependents"]=="3+") & (df["ApplicantIncome"] > urban_area)

# %%
df[condition8]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 34   LP001100   Male      No         3+      Graduate            No
# 126  LP001448   Male     Yes         3+      Graduate            No
# 155  LP001536   Male     Yes         3+      Graduate            No
# 177  LP001610   Male     Yes         3+      Graduate            No
# 213  LP001715   Male     Yes         3+  Not Graduate           Yes
# 324  LP002065   Male     Yes         3+      Graduate            No
# 376  LP002219   Male     Yes         3+      Graduate            No
# 390  LP002255   Male      No         3+      Graduate            No
# 391  LP002262   Male     Yes         3+      Graduate            No
# 409  LP002317   Male     Yes         3+      Graduate            No
# 522  LP002692   Male     Yes         3+      Graduate           Yes
# 539  LP002740   Male     Yes         3+      Graduate            No
# 557  LP002795   Male     Yes         3+      Graduate           Yes
# ...

# %% [markdown]
# The bank is considering the property area as a factor in loan approval. Specifically, favoring applicants who live in rural or semiurban areas compared to urban areas.

# %%
rural_area =  df[(df["Property_Area"]=="Rural") | (df["Property_Area"]=="Semiurban") &(df["Loan_Status"]=="Y")]["ApplicantIncome"].mean()

# %%
print("the average applicant income of those customers who are from non-urban areas",rural_area)
# Out:
# the average applicant income of those customers who are from non-urban areas 5422.480446927374
